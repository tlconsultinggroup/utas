# %% [markdown]
# # Task 1. Converting NetCDF Files to ZARR Format
# ## Q1. What would be your chunking strategy to make the resulting file more efficiently accessed
# - Make chunks similar in shape to the entire array so that the number of chunks to read a row or column is about the same to average access time across the dimensions.
# - If data access is more likely to be read across one dimension then you can chunk across the other dimensions.
# - The chunk size should ideally be a multiple of the disk block size of the target filesystem to minimize reading extra disk blocks per chunk.
# - Larger chunks can be more efficient, however should take account of the machine memory size as large blocks are harder to load into memory gaps.
# ## Q2. This dataset is updated daily. If you would like to automate the ZARR conversion to update daily, what will be your strategy?
# - Schedule an incremental job daily to check for and append new source data files to the target.

# %%
## Install Python dependencies

# %%
pip install -r requirements.txt
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: h5netcdf in /home/kevs/.local/lib/python3.10/site-packages (from -r requirements.txt (line 1)) (1.3.0)
# Requirement already satisfied: xarray in /home/kevs/.local/lib/python3.10/site-packages (from -r requirements.txt (line 2)) (2024.2.0)
# Requirement already satisfied: netCDF4 in /home/kevs/.local/lib/python3.10/site-packages (from -r requirements.txt (line 3)) (1.6.5)
# Requirement already satisfied: siphon in /home/kevs/.local/lib/python3.10/site-packages (from -r requirements.txt (line 4)) (0.9)
# Requirement already satisfied: fsspec in /home/kevs/.local/lib/python3.10/site-packages (from -r requirements.txt (line 5)) (2024.2.0)
# Requirement already satisfied: requests in /home/kevs/.local/lib/python3.10/site-packages (from -r requirements.txt (line 6)) (2.31.0)
# Requirement already satisfied: aiohttp in /home/kevs/.local/lib/python3.10/site-packages (from -r requirements.txt (line 7)) (3.9.3)
# Requirement already satisfied: dask in /home/kevs/.local/lib/python3.10/site-packages (from -r requirements.txt (line 8)) (2024.2.1)
# Requirement already satisfied: zarr in /home/kevs/.local/lib/python3.10/site-packages (from -r requirements.txt (line 9)) (2.17.0)
# Requirement already satisfied: pyarrow in /home/kevs/.local/lib/python3.10/site-packages (from -r requirements.txt (line 10)) (15.0.0)
# Requirement already satisfied: geopandas in /home/kevs/.local/lib/python3.10/site-packages (from -r requirements.txt (line 11)) (0.14.3)
# Requirement already satisfied: dask-geopandas in /home/kevs/.local/lib/python3.10/site-packages (from -r requirements.txt (line 12)) (0.3.1)
# Requirement already satisfied: s3fs in /home/kevs/.local/lib/python3.10/site-packages (from -r requirements.txt (line 13)) (2024.2.0)
# Requirement already satisfied: packaging in /home/kevs/.local/lib/python3.10/site-packages (from h5netcdf->-r requirements.txt (line 1)) (23.2)
# Requirement already satisfied: h5py in /home/kevs/.local/lib/python3.10/site-packages (from h5netcdf->-r requirements.txt (line 1)) (3.10.0)
# Requirement already satisfied: numpy>=1.23 in /home/kevs/.local/lib/python3.10/site-packages (from xarray->-r requirements.txt (line 2)) (1.26.4)
# Requirement already satisfied: pandas>=1.5 in /home/kevs/.local/lib/python3.10/site-packages (from xarray->-r requirements.txt (line 2)) (2.2.1)
# Requirement already satisfied: certifi in /home/kevs/.local/lib/python3.10/site-packages (from netCDF4->-r requirements.txt (line 3)) (2024.2.2)
# Requirement already satisfied: cftime in /home/kevs/.local/lib/python3.10/site-packages (from netCDF4->-r requirements.txt (line 3)) (1.6.3)
# Requirement already satisfied: protobuf>=3.0.0a3 in /home/kevs/.local/lib/python3.10/site-packages (from siphon->-r requirements.txt (line 4)) (5.26.0rc3)
# Requirement already satisfied: beautifulsoup4>=4.6 in /home/kevs/.local/lib/python3.10/site-packages (from siphon->-r requirements.txt (line 4)) (4.12.3)
# Requirement already satisfied: idna<4,>=2.5 in /home/kevs/.local/lib/python3.10/site-packages (from requests->-r requirements.txt (line 6)) (3.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/kevs/.local/lib/python3.10/site-packages (from requests->-r requirements.txt (line 6)) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/kevs/.local/lib/python3.10/site-packages (from requests->-r requirements.txt (line 6)) (2.0.7)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/kevs/.local/lib/python3.10/site-packages (from aiohttp->-r requirements.txt (line 7)) (1.4.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /home/kevs/.local/lib/python3.10/site-packages (from aiohttp->-r requirements.txt (line 7)) (4.0.3)
# Requirement already satisfied: yarl<2.0,>=1.0 in /home/kevs/.local/lib/python3.10/site-packages (from aiohttp->-r requirements.txt (line 7)) (1.9.4)
# Requirement already satisfied: attrs>=17.3.0 in /home/kevs/.local/lib/python3.10/site-packages (from aiohttp->-r requirements.txt (line 7)) (23.2.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/kevs/.local/lib/python3.10/site-packages (from aiohttp->-r requirements.txt (line 7)) (1.3.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/kevs/.local/lib/python3.10/site-packages (from aiohttp->-r requirements.txt (line 7)) (6.0.5)
# Requirement already satisfied: click>=8.1 in /home/kevs/.local/lib/python3.10/site-packages (from dask->-r requirements.txt (line 8)) (8.1.7)
# Requirement already satisfied: pyyaml>=5.3.1 in /home/kevs/.local/lib/python3.10/site-packages (from dask->-r requirements.txt (line 8)) (6.0.1)
# Requirement already satisfied: toolz>=0.10.0 in /home/kevs/.local/lib/python3.10/site-packages (from dask->-r requirements.txt (line 8)) (0.12.1)
# Requirement already satisfied: cloudpickle>=1.5.0 in /home/kevs/.local/lib/python3.10/site-packages (from dask->-r requirements.txt (line 8)) (3.0.0)
# Requirement already satisfied: partd>=1.2.0 in /home/kevs/.local/lib/python3.10/site-packages (from dask->-r requirements.txt (line 8)) (1.4.1)
# Requirement already satisfied: importlib-metadata>=4.13.0 in /home/kevs/.local/lib/python3.10/site-packages (from dask->-r requirements.txt (line 8)) (7.0.1)
# Requirement already satisfied: asciitree in /home/kevs/.local/lib/python3.10/site-packages (from zarr->-r requirements.txt (line 9)) (0.3.3)
# Requirement already satisfied: numcodecs>=0.10.0 in /home/kevs/.local/lib/python3.10/site-packages (from zarr->-r requirements.txt (line 9)) (0.12.1)
# Requirement already satisfied: fasteners in /home/kevs/.local/lib/python3.10/site-packages (from zarr->-r requirements.txt (line 9)) (0.19)
# Requirement already satisfied: fiona>=1.8.21 in /home/kevs/.local/lib/python3.10/site-packages (from geopandas->-r requirements.txt (line 11)) (1.9.5)
# Requirement already satisfied: pyproj>=3.3.0 in /home/kevs/.local/lib/python3.10/site-packages (from geopandas->-r requirements.txt (line 11)) (3.6.1)
# Requirement already satisfied: shapely>=1.8.0 in /home/kevs/.local/lib/python3.10/site-packages (from geopandas->-r requirements.txt (line 11)) (2.0.3)
# Requirement already satisfied: distributed>=2021.06.0 in /home/kevs/.local/lib/python3.10/site-packages (from dask-geopandas->-r requirements.txt (line 12)) (2024.2.1)
# Requirement already satisfied: aiobotocore<3.0.0,>=2.5.4 in /home/kevs/.local/lib/python3.10/site-packages (from s3fs->-r requirements.txt (line 13)) (2.12.1)
# Requirement already satisfied: aioitertools<1.0.0,>=0.5.1 in /home/kevs/.local/lib/python3.10/site-packages (from aiobotocore<3.0.0,>=2.5.4->s3fs->-r requirements.txt (line 13)) (0.11.0)
# Requirement already satisfied: botocore<1.34.52,>=1.34.41 in /home/kevs/.local/lib/python3.10/site-packages (from aiobotocore<3.0.0,>=2.5.4->s3fs->-r requirements.txt (line 13)) (1.34.51)
# Requirement already satisfied: wrapt<2.0.0,>=1.10.10 in /home/kevs/.local/lib/python3.10/site-packages (from aiobotocore<3.0.0,>=2.5.4->s3fs->-r requirements.txt (line 13)) (1.16.0)
# Requirement already satisfied: soupsieve>1.2 in /home/kevs/.local/lib/python3.10/site-packages (from beautifulsoup4>=4.6->siphon->-r requirements.txt (line 4)) (2.5)
# Requirement already satisfied: sortedcontainers>=2.0.5 in /home/kevs/.local/lib/python3.10/site-packages (from distributed>=2021.06.0->dask-geopandas->-r requirements.txt (line 12)) (2.4.0)
# Requirement already satisfied: msgpack>=1.0.0 in /home/kevs/.local/lib/python3.10/site-packages (from distributed>=2021.06.0->dask-geopandas->-r requirements.txt (line 12)) (1.0.8)
# Requirement already satisfied: tblib>=1.6.0 in /home/kevs/.local/lib/python3.10/site-packages (from distributed>=2021.06.0->dask-geopandas->-r requirements.txt (line 12)) (3.0.0)
# Requirement already satisfied: locket>=1.0.0 in /home/kevs/.local/lib/python3.10/site-packages (from distributed>=2021.06.0->dask-geopandas->-r requirements.txt (line 12)) (1.0.0)
# Requirement already satisfied: jinja2>=2.10.3 in /home/kevs/.local/lib/python3.10/site-packages (from distributed>=2021.06.0->dask-geopandas->-r requirements.txt (line 12)) (3.1.3)
# Requirement already satisfied: tornado>=6.0.4 in /home/kevs/.local/lib/python3.10/site-packages (from distributed>=2021.06.0->dask-geopandas->-r requirements.txt (line 12)) (6.4)
# Requirement already satisfied: zict>=3.0.0 in /home/kevs/.local/lib/python3.10/site-packages (from distributed>=2021.06.0->dask-geopandas->-r requirements.txt (line 12)) (3.0.0)
# Requirement already satisfied: psutil>=5.7.2 in /home/kevs/.local/lib/python3.10/site-packages (from distributed>=2021.06.0->dask-geopandas->-r requirements.txt (line 12)) (5.9.8)
# Requirement already satisfied: setuptools in /usr/lib/python3/dist-packages (from fiona>=1.8.21->geopandas->-r requirements.txt (line 11)) (59.6.0)
# Requirement already satisfied: cligj>=0.5 in /home/kevs/.local/lib/python3.10/site-packages (from fiona>=1.8.21->geopandas->-r requirements.txt (line 11)) (0.7.2)
# Requirement already satisfied: six in /home/kevs/.local/lib/python3.10/site-packages (from fiona>=1.8.21->geopandas->-r requirements.txt (line 11)) (1.16.0)
# Requirement already satisfied: click-plugins>=1.0 in /home/kevs/.local/lib/python3.10/site-packages (from fiona>=1.8.21->geopandas->-r requirements.txt (line 11)) (1.1.1)
# Requirement already satisfied: zipp>=0.5 in /usr/lib/python3/dist-packages (from importlib-metadata>=4.13.0->dask->-r requirements.txt (line 8)) (1.0.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/kevs/.local/lib/python3.10/site-packages (from pandas>=1.5->xarray->-r requirements.txt (line 2)) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/kevs/.local/lib/python3.10/site-packages (from pandas>=1.5->xarray->-r requirements.txt (line 2)) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /home/kevs/.local/lib/python3.10/site-packages (from pandas>=1.5->xarray->-r requirements.txt (line 2)) (2024.1)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from botocore<1.34.52,>=1.34.41->aiobotocore<3.0.0,>=2.5.4->s3fs->-r requirements.txt (line 13)) (1.0.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/kevs/.local/lib/python3.10/site-packages (from jinja2>=2.10.3->distributed>=2021.06.0->dask-geopandas->-r requirements.txt (line 12)) (2.1.5)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Convert 2023 NetCDF files to ZARR

# %%
from siphon.catalog import TDSCatalog
import xarray as xr
import fsspec

def filter_dict_by_extension(input_dict, extensions):
    return {key: input_dict[key] for key in input_dict if key.endswith(extensions)}

# List the catalog references in P1D
cat_p1d = TDSCatalog('https://thredds.aodn.org.au/thredds/catalog/IMOS/SRS/OC/gridded/aqua/P1D/catalog.xml')
print(list(cat_p1d.catalog_refs))

# Get the '2023' catalog reference and print it out
catref_2023 = cat_p1d.catalog_refs['2023']
print(f"name={catref_2023.name}, href={catref_2023.href}, title={catref_2023.title}")

# Follow the '2023' catalog which returns a new TDSCatalog
cat_2023 = catref_2023.follow()
print(list(cat_2023.catalog_refs))

# Get the '01' catalog reference and print it out
catref_2023_01 = cat_2023.catalog_refs['01']
print(f"name={catref_2023_01.name}, href={catref_2023_01.href}, title={catref_2023_01.title}")

# Follow the '01' catalog which returns a new TDSCatalog
cat_2023_01 = catref_2023_01.follow()

# List the catalog refs, which is empty as there are none in month catalog
print(list(cat_2023_01.catalog_refs))

# List the services
for compound_service in cat_2023_01.services:
    print(f"name={compound_service.name}, service_type={compound_service.service_type}")
    for simple_service in compound_service.services:
        print(f"\tname={simple_service.name}, service_type={simple_service.service_type}, access_urls={simple_service.access_urls}")

# Filter the dataset for specific extension: .aust.ipar.nc
filtered_dataset = filter_dict_by_extension(cat_2023_01.datasets, '.aust.ipar.nc')
print(filtered_dataset)

# Get the list of 2023-01 NetCDF data files
nc_files_list = [fsspec.open(ds.access_urls['HTTPServer']).open() for ds in filtered_dataset.values()]
# nc_files_list = list(ds. for ds in filtered_dataset.values())
print(nc_files_list)

ds = xr.open_mfdataset(nc_files_list, engine='h5netcdf', parallel=True, chunks={'time': 1})
display(ds)

ds.to_zarr('data.zarr', mode='w')
# Out:
# ['2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022', '2023', '2024']
# name=, href=https://thredds.aodn.org.au/thredds/catalog/IMOS/SRS/OC/gridded/aqua/P1D/2023/catalog.xml, title=2023
# ['01', '02', '03', '04', '05', '06', '07', '08', '09', '10', '11', '12']
# name=, href=https://thredds.aodn.org.au/thredds/catalog/IMOS/SRS/OC/gridded/aqua/P1D/2023/01/catalog.xml, title=01
# []
# name=regGriddedServices, service_type=Compound
# 	name=dapService, service_type=OPENDAP, access_urls={}
# 	name=httpService, service_type=HTTPServer, access_urls={}
# 	name=wmsService, service_type=WMS, access_urls={}
# {'A.P1D.20230101T053000Z.aust.ipar.nc': A.P1D.20230101T053000Z.aust.ipar.nc, 'A.P1D.20230102T053000Z.aust.ipar.nc': A.P1D.20230102T053000Z.aust.ipar.nc, 'A.P1D.20230103T053000Z.aust.ipar.nc': A.P1D.20230103T053000Z.aust.ipar.nc, 'A.P1D.20230104T053000Z.aust.ipar.nc': A.P1D.20230104T053000Z.aust.ipar.nc, 'A.P1D.20230105T053000Z.aust.ipar.nc': A.P1D.20230105T053000Z.aust.ipar.nc, 'A.P1D.20230106T053000Z.aust.ipar.nc': A.P1D.20230106T053000Z.aust.ipar.nc, 'A.P1D.20230107T053000Z.aust.ipar.nc': A.P1D.20230107T053000Z.aust.ipar.nc, 'A.P1D.20230108T053000Z.aust.ipar.nc': A.P1D.20230108T053000Z.aust.ipar.nc, 'A.P1D.20230109T053000Z.aust.ipar.nc': A.P1D.20230109T053000Z.aust.ipar.nc, 'A.P1D.20230110T053000Z.aust.ipar.nc': A.P1D.20230110T053000Z.aust.ipar.nc, 'A.P1D.20230111T053000Z.aust.ipar.nc': A.P1D.20230111T053000Z.aust.ipar.nc, 'A.P1D.20230112T053000Z.aust.ipar.nc': A.P1D.20230112T053000Z.aust.ipar.nc, 'A.P1D.20230113T053000Z.aust.ipar.nc': A.P1D.20230113T053000Z.aust.ipar.nc, 'A.P1D.20230114T053000Z.aust.ipar.nc': A.P1D.20230114T053000Z.aust.ipar.nc, 'A.P1D.20230115T053000Z.aust.ipar.nc': A.P1D.20230115T053000Z.aust.ipar.nc, 'A.P1D.20230116T053000Z.aust.ipar.nc': A.P1D.20230116T053000Z.aust.ipar.nc, 'A.P1D.20230117T053000Z.aust.ipar.nc': A.P1D.20230117T053000Z.aust.ipar.nc, 'A.P1D.20230118T053000Z.aust.ipar.nc': A.P1D.20230118T053000Z.aust.ipar.nc, 'A.P1D.20230119T053000Z.aust.ipar.nc': A.P1D.20230119T053000Z.aust.ipar.nc, 'A.P1D.20230120T053000Z.aust.ipar.nc': A.P1D.20230120T053000Z.aust.ipar.nc, 'A.P1D.20230121T053000Z.aust.ipar.nc': A.P1D.20230121T053000Z.aust.ipar.nc, 'A.P1D.20230122T053000Z.aust.ipar.nc': A.P1D.20230122T053000Z.aust.ipar.nc, 'A.P1D.20230123T053000Z.aust.ipar.nc': A.P1D.20230123T053000Z.aust.ipar.nc, 'A.P1D.20230124T053000Z.aust.ipar.nc': A.P1D.20230124T053000Z.aust.ipar.nc, 'A.P1D.20230125T053000Z.aust.ipar.nc': A.P1D.20230125T053000Z.aust.ipar.nc, 'A.P1D.20230126T053000Z.aust.ipar.nc': A.P1D.20230126T053000Z.aust.ipar.nc, 'A.P1D.20230127T053000Z.aust.ipar.nc': A.P1D.20230127T053000Z.aust.ipar.nc, 'A.P1D.20230128T053000Z.aust.ipar.nc': A.P1D.20230128T053000Z.aust.ipar.nc, 'A.P1D.20230129T053000Z.aust.ipar.nc': A.P1D.20230129T053000Z.aust.ipar.nc, 'A.P1D.20230130T053000Z.aust.ipar.nc': A.P1D.20230130T053000Z.aust.ipar.nc, 'A.P1D.20230131T053000Z.aust.ipar.nc': A.P1D.20230131T053000Z.aust.ipar.nc}
# [<File-like object HTTPFileSystem, https://thredds.aodn.org.au/thredds/fileServer/IMOS/SRS/OC/gridded/aqua/P1D/2023/01/A.P1D.20230101T053000Z.aust.ipar.nc>, <File-like object HTTPFileSystem, https://thredds.aodn.org.au/thredds/fileServer/IMOS/SRS/OC/gridded/aqua/P1D/2023/01/A.P1D.20230102T053000Z.aust.ipar.nc>, <File-like object HTTPFileSystem, https://thredds.aodn.org.au/thredds/fileServer/IMOS/SRS/OC/gridded/aqua/P1D/2023/01/A.P1D.20230103T053000Z.aust.ipar.nc>, <File-like object HTTPFileSystem, https://thredds.aodn.org.au/thredds/fileServer/IMOS/SRS/OC/gridded/aqua/P1D/2023/01/A.P1D.20230104T053000Z.aust.ipar.nc>, <File-like object HTTPFileSystem, https://thredds.aodn.org.au/thredds/fileServer/IMOS/SRS/OC/gridded/aqua/P1D/2023/01/A.P1D.20230105T053000Z.aust.ipar.nc>, <File-like object HTTPFileSystem, https://thredds.aodn.org.au/thredds/fileServer/IMOS/SRS/OC/gridded/aqua/P1D/2023/01/A.P1D.20230106T053000Z.aust.ipar.nc>, <File-like object HTTPFileSystem, https://thredds.aodn.org.au/thredds/fileServer/IMOS/SRS/OC/gridded/aqua/P1D/2023/01/A.P1D.20230107T053000Z.aust.ipar.nc>, <File-like object HTTPFileSystem, https://thredds.aodn.org.au/thredds/fileServer/IMOS/SRS/OC/gridded/aqua/P1D/2023/01/A.P1D.20230108T053000Z.aust.ipar.nc>, <File-like object HTTPFileSystem, https://thredds.aodn.org.au/thredds/fileServer/IMOS/SRS/OC/gridded/aqua/P1D/2023/01/A.P1D.20230109T053000Z.aust.ipar.nc>, <File-like object HTTPFileSystem, https://thredds.aodn.org.au/thredds/fileServer/IMOS/SRS/OC/gridded/aqua/P1D/2023/01/A.P1D.20230110T053000Z.aust.ipar.nc>, <File-like object HTTPFileSystem, https://thredds.aodn.org.au/thredds/fileServer/IMOS/SRS/OC/gridded/aqua/P1D/2023/01/A.P1D.20230111T053000Z.aust.ipar.nc>, <File-like object HTTPFileSystem, https://thredds.aodn.org.au/thredds/fileServer/IMOS/SRS/OC/gridded/aqua/P1D/2023/01/A.P1D.20230112T053000Z.aust.ipar.nc>, <File-like object HTTPFileSystem, https://thredds.aodn.org.au/thredds/fileServer/IMOS/SRS/OC/gridded/aqua/P1D/2023/01/A.P1D.20230113T053000Z.aust.ipar.nc>, <File-like object HTTPFileSystem, https://thredds.aodn.org.au/thredds/fileServer/IMOS/SRS/OC/gridded/aqua/P1D/2023/01/A.P1D.20230114T053000Z.aust.ipar.nc>, <File-like object HTTPFileSystem, https://thredds.aodn.org.au/thredds/fileServer/IMOS/SRS/OC/gridded/aqua/P1D/2023/01/A.P1D.20230115T053000Z.aust.ipar.nc>, <File-like object HTTPFileSystem, https://thredds.aodn.org.au/thredds/fileServer/IMOS/SRS/OC/gridded/aqua/P1D/2023/01/A.P1D.20230116T053000Z.aust.ipar.nc>, <File-like object HTTPFileSystem, https://thredds.aodn.org.au/thredds/fileServer/IMOS/SRS/OC/gridded/aqua/P1D/2023/01/A.P1D.20230117T053000Z.aust.ipar.nc>, <File-like object HTTPFileSystem, https://thredds.aodn.org.au/thredds/fileServer/IMOS/SRS/OC/gridded/aqua/P1D/2023/01/A.P1D.20230118T053000Z.aust.ipar.nc>, <File-like object HTTPFileSystem, https://thredds.aodn.org.au/thredds/fileServer/IMOS/SRS/OC/gridded/aqua/P1D/2023/01/A.P1D.20230119T053000Z.aust.ipar.nc>, <File-like object HTTPFileSystem, https://thredds.aodn.org.au/thredds/fileServer/IMOS/SRS/OC/gridded/aqua/P1D/2023/01/A.P1D.20230120T053000Z.aust.ipar.nc>, <File-like object HTTPFileSystem, https://thredds.aodn.org.au/thredds/fileServer/IMOS/SRS/OC/gridded/aqua/P1D/2023/01/A.P1D.20230121T053000Z.aust.ipar.nc>, <File-like object HTTPFileSystem, https://thredds.aodn.org.au/thredds/fileServer/IMOS/SRS/OC/gridded/aqua/P1D/2023/01/A.P1D.20230122T053000Z.aust.ipar.nc>, <File-like object HTTPFileSystem, https://thredds.aodn.org.au/thredds/fileServer/IMOS/SRS/OC/gridded/aqua/P1D/2023/01/A.P1D.20230123T053000Z.aust.ipar.nc>, <File-like object HTTPFileSystem, https://thredds.aodn.org.au/thredds/fileServer/IMOS/SRS/OC/gridded/aqua/P1D/2023/01/A.P1D.20230124T053000Z.aust.ipar.nc>, <File-like object HTTPFileSystem, https://thredds.aodn.org.au/thredds/fileServer/IMOS/SRS/OC/gridded/aqua/P1D/2023/01/A.P1D.20230125T053000Z.aust.ipar.nc>, <File-like object HTTPFileSystem, https://thredds.aodn.org.au/thredds/fileServer/IMOS/SRS/OC/gridde ...
# <xarray.Dataset> Size: 9GB
# Dimensions:    (time: 31, latitude: 7001, longitude: 10001)
# Coordinates:
#   * time       (time) datetime64[ns] 248B 2023-01-01T05:30:00 ... 2023-01-31T...
#   * latitude   (latitude) float64 56kB 10.0 9.99 9.98 ... -59.98 -59.99 -60.0
#   * longitude  (longitude) float64 80kB 80.0 80.01 80.02 ... 180.0 180.0 180.0
# Data variables:
#     ipar       (time, latitude, longitude) float32 9GB dask.array<chunksize=(1, 1401, 2001), meta=np.ndarray>
# Attributes:
#     history:      File initialised at 2023-02-22T23:16:26.165085\nInitialised...
#     Conventions:  CF-1.6
#     source_path:  imos-srs/archive/oc/aqua/v202302/1d/2023/01/A20230101.L2OC_...
